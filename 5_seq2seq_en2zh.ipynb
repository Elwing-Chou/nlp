# %%
# 下載想要的語言版本 -q: 安靜模式
# !wget -q http://www.manythings.org/anki/cmn-eng.zip
# 解壓縮zip -o: 覆蓋原本
# !unzip -o cmn-eng.zip
# Out:
# Archive:  cmn-eng.zip
#   inflating: cmn.txt
#   inflating: _about.txt

# %%
import pandas as pd
df = pd.read_csv("cmn.txt",
                 sep="\t",
                 header=None)
df.columns = ["English", "Chinese", "By"]
df
# Out:
#                                                  English  \
# 0                                                    Hi.
# 1                                                    Hi.
# 2                                                   Run.
# 3                                                  Stop!
# 4                                                  Wait!
# ...                                                  ...
# 29663  If you don't want to put on sunscreen, that's ...
# 29664  Even now, I occasionally think I'd like to see...
# 29665  It's very easy to sound natural in your own na...
# 29666  I got fired from the company, but since I have...
# 29667  If a person has not had a chance to acquire hi...
#
#                                             Chinese  \
# 0                                                嗨。
# 1                                               你好。
# 2                                             你用跑的。
# 3                                               住手！
# 4                                               等等！
# ...                                             ...
# 29663                      你不想涂防晒霜是你的问题，但是晒伤了不要来抱怨。
# 29664            即使是现在，我偶尔还是想见到你。不是今天的你，而是我记忆中曾经的你。
# 29665                  你很容易把母语说得通顺流畅，却很容易把非母语说得不自然。
# 29666              虽然我被公司解雇了，但是我还有点存款，所以目前不用担心生计问题。
# 29667  如果一個人在成人前沒有機會習得目標語言，他對該語言的認識達到母語者程度的機會是相當小的。
#
#                                                       By
# 0      CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1      CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2      CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# 3      CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# 4      CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# ...                                                  ...
# 29663  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 29664  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 29665  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 29666  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 29667  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
#
# [29668 rows x 3 columns]

# %%
# 使用opencc將簡中翻譯成繁中
# !pip install opencc-python-reimplemented
# Out:
# Collecting opencc-python-reimplemented
#   Downloading opencc_python_reimplemented-0.1.7-py2.py3-none-any.whl (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: opencc-python-reimplemented
# Successfully installed opencc-python-reimplemented-0.1.7

# %%
from opencc import OpenCC
t = OpenCC("s2tw")
df["Chinese"] = df["Chinese"].apply(lambda s:t.convert(s))
df = df.drop(["By"], axis=1)
df.to_csv("en_zh.csv")
df
# Out:
#                                                  English  \
# 0                                                    Hi.
# 1                                                    Hi.
# 2                                                   Run.
# 3                                                  Stop!
# 4                                                  Wait!
# ...                                                  ...
# 29663  If you don't want to put on sunscreen, that's ...
# 29664  Even now, I occasionally think I'd like to see...
# 29665  It's very easy to sound natural in your own na...
# 29666  I got fired from the company, but since I have...
# 29667  If a person has not had a chance to acquire hi...
#
#                                             Chinese
# 0                                                嗨。
# 1                                               你好。
# 2                                             你用跑的。
# 3                                               住手！
# 4                                               等等！
# ...                                             ...
# 29663                      你不想塗防曬霜是你的問題，但是曬傷了不要來抱怨。
# 29664            即使是現在，我偶爾還是想見到你。不是今天的你，而是我記憶中曾經的你。
# 29665                  你很容易把母語說得通順流暢，卻很容易把非母語說得不自然。
# 29666              雖然我被公司解僱了，但是我還有點存款，所以目前不用擔心生計問題。
# 29667  如果一個人在成人前沒有機會習得目標語言，他對該語言的認識達到母語者程度的機會是相當小的。
#
# [29668 rows x 2 columns]

# %%
# 預處理Step1. 數出有多少種不同的詞彙
inputs = []
targets = []
input_characters = set()
target_characters = set()

for target_text, input_text in zip(df["Chinese"], df["English"]):
    # 這裡比較特別, 在真正最後預測的時候你是喂start token給decoder
    # 再等到decoder輸出end token結束
    # 所以我們自定義 \t 為 start token, \n 為 decode token
    target_text = '\t' + target_text + '\n'
    # encoder 吃的不用加 \t \n
    inputs.append(input_text)
    # decoder 吃的加 \t \n
    targets.append(target_text)
    # 把不同種的詞紀錄, 由於我們使用set, 所以會自動把重複的去掉
    for char in input_text:
        input_characters.add(char)
    for char in target_text:
        target_characters.add(char)

# %%
# 把我們的一些參數列出來一下
# 順便先計算最長的輸入和輸出長度, 等等喂給模型
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters) + 1
num_decoder_tokens = len(target_characters) + 1
max_encoder_seq_length = max([len(txt) for txt in inputs])
max_decoder_seq_length = max([len(txt) for txt in targets])

print("資料集筆數:", len(inputs))
print("輸入的所有字彙:", num_encoder_tokens)
print("輸出的所有字彙:", num_decoder_tokens)
print("最長的輸入句子有多長:", max_encoder_seq_length)
print('最長的輸出句子有多長:', max_decoder_seq_length)
# Out:
# 資料集筆數: 29668
# 輸入的所有字彙: 79
# 輸出的所有字彙: 2923
# 最長的輸入句子有多長: 163
# 最長的輸出句子有多長: 46

# %%
# 給每一個字彙一個編號, 輸入輸出都要
# 建立 文字 -> 數字 的查詢辭典
# 養成習慣留一個 <PAD> 字符, 我們習慣給0, 到時候不夠長度的句子我們就補0
inputs_char_int = {char:i+1 for i, char in enumerate(input_characters)}
inputs_char_int["<PAD>"] = 0
targets_char_int = {char:i+1 for i, char in enumerate(target_characters)}
targets_char_int["<PAD>"] = 0

# %%
# 建立 數字 -> 文字 的查詢辭典
inputs_int_char = {i:char for char, i in inputs_char_int.items()}
targets_int_char = {i:char for char, i in targets_char_int.items()}

# %%
# 訓練參數
# batch: 多少筆資料更新一次
# embedding dimension: 先把每一種不同的東西降維
# dim: LSTM/RNN的維度
batch_size = 64
embedding_dim = 256
dim = 256

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, TimeDistributed

input1 = Input(shape=(None,))
x = Embedding(num_encoder_tokens, embedding_dim, mask_zero=True)(input1)
x, state_h, state_c = LSTM(dim, return_state=True)(x)

input2 = Input(shape=(None,))
y = Embedding(num_decoder_tokens, embedding_dim, name="decoder_embedding", mask_zero=True)(input2)
y, _, _ = LSTM(dim, return_sequences=True,
               return_state=True,
               name="decoder_lstm")(y, initial_state=[state_h, state_c])
y = Dense(num_decoder_tokens, activation='softmax', name="decoder_dense")(y)

model = Model(inputs=[input1, input2], outputs=y)
model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, None)]               0         []
#
#  input_16 (InputLayer)       [(None, None)]               0         []
#
#  embedding_3 (Embedding)     (None, None, 256)            20224     ['input_15[0][0]']
#
#  decoder_embedding (Embeddi  (None, None, 256)            748288    ['input_16[0][0]']
#  ng)
#
#  lstm_3 (LSTM)               [(None, 256),                525312    ['embedding_3[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  decoder_lstm (LSTM)         [(None, None, 256),          525312    ['decoder_embedding[0][0]',
#                               (None, 256),                           'lstm_3[0][1]',
#                               (None, 256)]                           'lstm_3[0][2]']
#
#  decoder_dense (Dense)       (None, None, 2923)           751211    ['decoder_lstm[0][0]']
#
# ==================================================================================================
# Total params: 2570347 (9.81 MB)
# Trainable params: 2570347 (9.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer="adam")

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import numpy as np
en = []
dein = []
deout = []
for sentence in inputs:
    l = [inputs_char_int[c] for c in sentence]
    en.append(l)
en = pad_sequences(en, maxlen=max_encoder_seq_length, padding="post")
for sentence in targets:
    l = [targets_char_int[c] for c in sentence[:-1]]
    dein.append(l)
    o = [targets_char_int[c] for c in sentence[1:]]
    deout.append(o)

dein = pad_sequences(dein, maxlen=max_decoder_seq_length, padding="post")
deout = pad_sequences(deout, maxlen=max_decoder_seq_length, padding="post")
deout = deout.reshape(len(deout), -1, 1)

# %%
# 輸入資料長的樣子
for seq in en[:10]:
    print([inputs_int_char[s] for s in seq])
# Out:
# ['H', 'i', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['H', 'i', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['R', 'u', 'n', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['S', 't', 'o', 'p', '!', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['W', 'a', 'i', 't', '!', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['W', 'a', 'i', 't', '!', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['B', 'e', 'g', 'i', 'n', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['H', 'e', 'l', 'l', 'o', '!', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['I', ' ', 't', 'r', 'y', '.', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['I', ' ', 'w', 'o', 'n', '!', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']

# %%
# 正確答案長的樣子
for seq in deout[:10]:
    print([targets_int_char[s[0]] for s in seq])
# Out:
# ['嗨', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['你', '好', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['你', '用', '跑', '的', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['住', '手', '！', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['等', '等', '！', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['等', '一', '下', '！', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['開', '始', '！', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['你', '好', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['我', '試', '試', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['我', '贏', '了', '。', '\n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']

# %%
# 大約訓練50~100次
model.fit([en, dein], deout,
          batch_size=batch_size,
          epochs=50,
          validation_split=0.1,
          verbose=2)
# Out:
# Epoch 1/50
# 418/418 - 8s - loss: 0.1806 - val_loss: 6.1153 - 8s/epoch - 19ms/step
# Epoch 2/50
# 418/418 - 9s - loss: 0.1736 - val_loss: 6.1564 - 9s/epoch - 21ms/step
# Epoch 3/50
# 418/418 - 9s - loss: 0.1641 - val_loss: 6.2389 - 9s/epoch - 21ms/step
# Epoch 4/50
# 418/418 - 8s - loss: 0.1590 - val_loss: 6.2940 - 8s/epoch - 18ms/step
# Epoch 5/50
# 418/418 - 9s - loss: 0.1499 - val_loss: 6.3696 - 9s/epoch - 21ms/step
# Epoch 6/50
# 418/418 - 9s - loss: 0.1406 - val_loss: 6.4162 - 9s/epoch - 20ms/step
# Epoch 7/50
# 418/418 - 8s - loss: 0.1393 - val_loss: 6.4699 - 8s/epoch - 18ms/step
# Epoch 8/50
# 418/418 - 9s - loss: 0.1319 - val_loss: 6.5291 - 9s/epoch - 21ms/step
# Epoch 9/50
# 418/418 - 8s - loss: 0.1250 - val_loss: 6.6220 - 8s/epoch - 20ms/step
# Epoch 10/50
# 418/418 - 8s - loss: 0.1183 - val_loss: 6.6762 - 8s/epoch - 19ms/step
# Epoch 11/50
# 418/418 - 9s - loss: 0.1170 - val_loss: 6.6920 - 9s/epoch - 21ms/step
# Epoch 12/50
# 418/418 - 8s - loss: 0.1124 - val_loss: 6.7444 - 8s/epoch - 19ms/step
# Epoch 13/50
# 418/418 - 9s - loss: 0.1096 - val_loss: 6.8056 - 9s/epoch - 21ms/step
# Epoch 14/50
# 418/418 - 9s - loss: 0.1097 - val_loss: 6.8396 - 9s/epoch - 21ms/step
# Epoch 15/50
# 418/418 - 8s - loss: 0.1061 - val_loss: 6.8776 - 8s/epoch - 18ms/step
# Epoch 16/50
# 418/418 - 9s - loss: 0.0948 - val_loss: 6.9345 - 9s/epoch - 21ms/step
# Epoch 17/50
# 418/418 - 9s - loss: 0.0917 - val_loss: 6.9539 - 9s/epoch - 21ms/step
# Epoch 18/50
# 418/418 - 8s - loss: 0.0891 - val_loss: 7.0171 - 8s/epoch - 18ms/step
# Epoch 19/50
# 418/418 - 9s - loss: 0.0908 - val_loss: 7.0750 - 9s/epoch - 21ms/step
# Epoch 20/50
# 418/418 - 9s - loss: 0.0900 - val_loss: 7.1072 - 9s/epoch - 21ms/step
# Epoch 21/50
# 418/418 - 8s - loss: 0.0882 - val_loss: 7.1278 - 8s/epoch - 18ms/step
# Epoch 22/50
# 418/418 - 9s - loss: 0.0853 - val_loss: 7.2169 - 9s/epoch - 21ms/step
# Epoch 23/50
# 418/418 - 9s - loss: 0.0849 - val_loss: 7.2753 - 9s/epoch - 21ms/step
# Epoch 24/50
# 418/418 - 8s - loss: 0.0748 - val_loss: 7.3073 - 8s/epoch - 18ms/step
# Epoch 25/50
# 418/418 - 9s - loss: 0.0647 - val_loss: 7.3178 - 9s/epoch - 21ms/step
# Epoch 26/50
# 418/418 - 8s - loss: 0.0667 - val_loss: 7.3815 - 8s/epoch - 19ms/step
# Epoch 27/50
# 418/418 - 8s - loss: 0.0752 - val_loss: 7.3841 - 8s/epoch - 19ms/step
# Epoch 28/50
# 418/418 - 9s - loss: 0.1039 - val_loss: 7.4126 - 9s/epoch - 21ms/step
# Epoch 29/50
# 418/418 - 8s - loss: 0.1053 - val_loss: 7.4577 - 8s/epoch - 18ms/step
# Epoch 30/50
# 418/418 - 8s - loss: 0.0732 - val_loss: 7.5028 - 8s/epoch - 20ms/step
# Epoch 31/50
# 418/418 - 9s - loss: 0.0541 - val_loss: 7.5138 - 9s/epoch - 20ms/step
# Epoch 32/50
# 418/418 - 8s - loss: 0.0452 - val_loss: 7.5685 - 8s/epoch - 18ms/step
# Epoch 33/50
# 418/418 - 9s - loss: 0.0451 - val_loss: 7.6142 - 9s/epoch - 21ms/step
# Epoch 34/50
# 418/418 - 9s - loss: 0.0547 - val_loss: 7.5769 - 9s/epoch - 21ms/step
# Epoch 35/50
# 418/418 - 8s - loss: 0.1743 - val_loss: 7.6415 - 8s/epoch - 18ms/step
# Epoch 36/50
# 418/418 - 9s - loss: 0.1277 - val_loss: 7.6092 - 9s/epoch - 21ms/step
# Epoch 37/50
# 418/418 - 9s - loss: 0.0640 - val_loss: 7.6483 - 9s/epoch - 21ms/step
# Epoch 38/50
# 418/418 - 8s - loss: 0.0413 - val_loss: 7.6796 - 8s/epoch - 18ms/step
# Epoch 39/50
# 418/418 - 9s - loss: 0.0367 - val_loss: 7.7131 - 9s/epoch - 21ms/step
# Epoch 40/50
# 418/418 - 8s - loss: 0.0361 - val_loss: 7.7428 - 8s/epoch - 19ms/step
# Epoch 41/50
# 418/418 - 8s - loss: 0.0381 - val_loss: 7.7645 - 8s/epoch - 19ms/step
# Epoch 42/50
# 418/418 - 9s - loss: 0.0541 - val_loss: 7.8173 - 9s/epoch - 21ms/step
# Epoch 43/50
# 418/418 - 8s - loss: 0.2223 - val_loss: 7.7413 - 8s/epoch - 18ms/step
# Epoch 44/50
# 418/418 - 9s - loss: 0.1028 - val_loss: 7.7735 - 9s/epoch - 20ms/step
# Epoch 45/50
# 418/418 - 9s - loss: 0.0521 - val_loss: 7.8168 - 9s/epoch - 21ms/step
# Epoch 46/50
# 418/418 - 8s - loss: 0.0369 - val_loss: 7.8435 - 8s/epoch - 19ms/step
# Epoch 47/50
# 418/418 - 9s - loss: 0.0331 - val_loss: 7.8836 - 9s/epoch - 20ms/step
# Epoch 48/50
# 418/418 - 9s - loss: 0.0353 - val_loss: 7.8928 - 9s/epoch - 21ms/step
# Epoch 49/50
# 418/418 - 8s - loss: 0.0367 - val_loss: 7.9059 - 8s/epoch - 18ms/step
# Epoch 50/50
# 418/418 - 9s - loss: 0.0581 - val_loss: 7.9791 - 9s/epoch - 21ms/step

# %%
# 測試一下原本的他有沒有學會
import numpy as np
infer_encoder = Model(inputs=input1, outputs=[state_h, state_c])

de_h = Input(shape=(dim,))
de_c = Input(shape=(dim,))
de = model.get_layer("decoder_embedding")(input2)
dex, next_h, next_c = model.get_layer("decoder_lstm")(de, initial_state=[de_h, de_c])
dex = model.get_layer("decoder_dense")(dex)
infer_decoder = Model(inputs=[input2, de_h, de_c],
                      outputs=[dex, next_h, next_c])

test = df.head(20)
for e, z in zip(test["English"], test["Chinese"]):
    print("Encode:", e)
    test_input1 = [inputs_char_int[c] for c in e]
    test_input1 = np.array([test_input1])
    h, c = infer_encoder.predict(test_input1, verbose=0)

    result = ""
    i = targets_char_int["\t"]
    while True:
        o, nexth, nextc = infer_decoder.predict([np.array([[i]]), h, c], verbose=0)
        index = o.argmax()
        result = result + targets_int_char[index]
        i, h, c = index, nexth, nextc
        if len(result) >= 100 or index == targets_char_int["\n"]:
            print("Decode:", result)
            break
# Out:
# Encode: Hi.
# Decode: 嗨。
#
# Encode: Hi.
# Decode: 嗨。
#
# Encode: Run.
# Decode: 你用跑的。
#
# Encode: Stop!
# Decode: 住手！
#
# Encode: Wait!
# Decode: 等等！
#
# Encode: Wait!
# Decode: 等等！
#
# Encode: Begin.
# Decode: 開始！
#
# Encode: Hello!
# Decode: 你好。
#
# Encode: I try.
# Decode: 我試試。
#
# Encode: I won!
# Decode: 我贏了。
#
# Encode: Oh no!
# Decode: 不會吧。
#
# Encode: Cheers!
# Decode: 乾杯!
#
# Encode: Got it?
# Decode: 知道了沒有？
#
# Encode: Got it?
# Decode: 知道了沒有？
#
# Encode: Got it?
# Decode: 知道了沒有？
#
# Encode: He ran.
# Decode: 他跑了。
#
# Encode: Hop in.
# Decode: 跳進來。
#
# Encode: I know.
# Decode: 我知道。
#
# Encode: I quit.
# Decode: 我退出。
#
# Encode: I quit.
# Decode: 我退出。

# %%
# 讓他試一下從沒看過的句子
finaltest = ["This is room 666",
             "This is my money",
             "I love your pencil",
             "This is my pencil",
             "I love Tom",
             "Tom love me"]
for e in finaltest:
    print("Encode:", e)
    test_input1 = [inputs_char_int[c] for c in e]
    test_input1 = pad_sequences(np.array([test_input1]), maxlen=max_encoder_seq_length, padding="post")
    h, c = infer_encoder.predict(test_input1, verbose=0)

    result = ""
    i = targets_char_int["\t"]
    while True:
        o, nexth, nextc = infer_decoder.predict([np.array([[i]]), h, c], verbose=0)
        index = o.argmax()
        result = result + targets_int_char[index]
        i, h, c = index, nexth, nextc
        if len(result) >= 100 or index == targets_char_int["\n"]:
            print("Decode:", result)
            break
# Out:
# Encode: This is room 666
# Decode: 這是箇爸。
#
# Encode: This is my money
# Decode: 這是我的錢。
#
# Encode: I love your pencil
# Decode: 我喜歡你的意見。
#
# Encode: This is my pencil
# Decode: 這是我的電話。
#
# Encode: I love Tom
# Decode: 我愛謝！
#
# Encode: Tom love me
# Decode: 湯姆愛我。
